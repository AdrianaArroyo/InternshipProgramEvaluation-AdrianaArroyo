# %% [markdown]
# <a href="https://colab.research.google.com/github/AdrianaArroyo/InternshipProgramEvaluation-AdrianaArroyo/blob/master/AdrianaAHInternshipEvaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Internship Program Evaluation**
#
# **Adriana Priscila Arroyo Hernández 208110343**
#
# **adrianapah10@gmail.com**
#
# Resolution time of the excercises: 7 hours.

# %% [markdown]
# ### **Exercise 1 - Data Modeling**

# %% [markdown]
# ### **1. Create a data model for CarSalesDataforReports Excel spreadsheet**

# %% [markdown]
# **Read Cardinalities:**
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# Each STOCK may have at most one COLOR.
# Each COLOR may have one or more STOCK.

# %% [markdown]
# For this exercise I did a conceptual data model and a logical data model and some corrections that I considered, for example:
#
# The name of tables in excel are in plural, but for better performance in the database, I wrote the names in the singular form.
#
# ![image.png](data:image/png;base64,...)
#
# Also, the variables have been written with the first word with a capital letter, I wrote the variables in camelCase, for use a standard. Also, I added types as integer, varchar, and date, also I made restrictions, such as the length of the words.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####**CONCEPTUAL DATA MODEL:**
#
# ![conceptualDataModel.png](data:image/png;base64,...)

# %% [markdown]
# ####**LOGICAL DATA MODEL:**
# ![logicalDataModel.png](data:image/png;base64,...)

# %% [markdown]
# ###**Exercise 2 - Object Oriented Programming**

# %% [markdown]
# ### **1. Define the required classes, methods and properties based on CarSalesDataforReports Excel file.**

# %% [markdown]
# ### **CLIENT**

# %%
class Client: 
  def __init__(self, clientID, countryID, clientName, address1, address2, town,
               county, postCode, region, outerPostCode, clientType, clientSize,
               clientSince, isCreditWorthy, isDealer):
    self.clientID = clientID
    self.countryID = countryID
    self.clientName = clientName
    self.address1 = address1
    self.address2 = address2
    self.town = town
    self.county = county
    self.postCode = postCode
    self.region = region
    self.outerPostCode = outerPostCode
    self.clientType = clientType
    self.clientSize = clientSize
    self.clientSince = clientSince
    self.isCreditWorthy = isCreditWorthy
    self.isDealer = isDealer

  def displayClient(self): 
    print('-----CLIENT----- ')
    print('ID: ', self.clientID )
    print('CountryId: ', self.countryID)
    print('Name: ', self.clientName )
    print('Address #1: ', self.address1)
    print('address #2: ', self.address2)
    print('Town: ', self.town)
    print('County: ', self.county)
    print('PostCode: ', self.postCode)
    print('Region: ', self.region)
    print('Outer PostCode: ', self.outerPostCode)
    print('Type: ', self.clientType)
    print('Size: ', self.clientSize)
    print('Since: ', self.clientSince)
    print('CreditWorthy: ', self.isCreditWorthy)
    print('Dealer: ', self.isDealer)

# %% [markdown]
# #### **Show results of Client**

# %%
client = Client(1, 'Aldo Motors', '4, Scale Street', '', 'Ottoxeter', 'Staffs', 'ST17 99RZ', 'East Midlans', 'ST', 1, 'Wholesaler', 'Large', '04/01/1998', True, False)
client.displayClient()
# Out:
# -----CLIENT-----
# ID:  1
# CountryId:  Aldo Motors
# Name:  4, Scale Street
# Address #1:
# address #2:  Ottoxeter
# Town:  Staffs
# County:  ST17 99RZ
# PostCode:  East Midlans
# Region:  ST
# Outer PostCode:  1
# Type:  Wholesaler
# Size:  Large
# Since:  04/01/1998
# CreditWorthy:  True
# Dealer:  False

# %% [markdown]
# ### **COLOR**

# %%
class Color: 
  def __init__(self, colorID, color):
    self.colorID = colorID
    self.color = color

  def displayColor(self):
    print('-----COLOR-----')
    print('ID:', self.colorID)
    print('Color:', self.color)

# %% [markdown]
# ### **Show results Color**

# %%
color = Color(1, 'Red')
color.displayColor()
# Out:
# -----COLOR-----
# ID: 1
# Color: Red

# %% [markdown]
# ### **COUNTRY**

# %%
class Country:
 def __init__(self, countryID, countryName, countryIsoCode):
  self.countryID = countryID
  self.countryName = countryName
  self.countryIsoCode = countryIsoCode

 def displayCountry(self):
    print('-----COUNTRY-----')
    print('ID: ', self.countryID)
    print('Name: ', self.countryName)
    print('ISO Code: ', self.countryIsoCode)

# %% [markdown]
# ### **Show results Country**

# %%
country = Country(4, 'Germany', 'DEU')
country.displayCountry()
# Out:
# -----COUNTRY-----
# ID:  4
# Name:  Germany
# ISO Code:  DEU

# %% [markdown]
# ### **STOCK**

# %%
class Stock:

  def __init__(self, stockID, make, model, colorID, vehicleType, costPrice,
               spareParts, laborCost, registrationDate, mileage, purchaseDate,
               vehicleAgeInYears):
    self.stockID = stockID
    self.make = make
    self.model = model
    self.colorID = colorID
    self.vehicleType = vehicleType
    self.costPrice = costPrice
    self.spareParts = spareParts
    self.laborCost = laborCost
    self.registrationDate = registrationDate
    self.mileage = mileage
    self.purchaseDate = purchaseDate
    self.vehicleAgeInYears = vehicleAgeInYears

  def displayStock(self): 
    print('-----STOCK----- ')
    print('ID: ', self.stockID)
    print('Make: ', self.make)
    print('Model: ', self.model)
    print('Color ID: ', self.colorID)
    print('Type: ', self.vehicleType)
    print('Price: ', self.costPrice)
    print('Spare parts: ', self.spareParts)
    print('Labor cost: ', self.laborCost)
    print('Registration: ', self.registrationDate)
    print('Mileage: ', self.mileage)
    print('Purchase Date: ', self.purchaseDate)
    print('Age in years: ', self.vehicleAgeInYears)

# %% [markdown]
# ### **Show results Stock**

# %%
stock = Stock(4, 'Rolls Royce', 'Silver Ghost', 2, 'Saloon', 88000, 85, 550,'05/01/1987', 127220, '01/01/2012', 31)
stock.displayStock()
# Out:
# -----STOCK-----
# ID:  4
# Make:  Rolls Royce
# Model:  Silver Ghost
# Color ID:  2
# Type:  Saloon
# Price:  88000
# Spare parts:  85
# Labor cost:  550
# Registration:  05/01/1987
# Mileage:  127220
# Purchase Date:  01/01/2012
# Age in years:  31

# %% [markdown]
# ### **INVOICE**

# %%
class Invoice:

  def __init__(self,invoiceID, invoiceNumber, clientID, invoiceDate,
               totalDiscount, deliveryCharge, invoiceDateKey):
    self.invoiceID = invoiceID
    self.invoiceNumber = invoiceNumber
    self.clientID = clientID
    self.invoiceDate = invoiceDate
    self.totalDiscount = totalDiscount
    self.deliveryCharge = deliveryCharge
    self.invoiceDateKey = invoiceDateKey

  def displayInvoice(self):
    print('-----INVOICE----- ')
    print('ID: ', self.invoiceID)
    print('Number: ', self.invoiceNumber)
    print('Client ID: ', self.clientID)
    print('Invoice Date: ', self.invoiceDate)
    print('Total discount: ', self.totalDiscount)
    print('DeliveryCharge: ', self.deliveryCharge)
    print('InvoiceDateKey: ', self.invoiceDateKey)

# %% [markdown]
# ### **Show results Invoice**

# %%
invoice = Invoice(1, '8B3D7F83-F42C-4523-A737-CDCBF7705B77', 1, '04/10/2012  12:00:00 a. m.', 500, 750, 20121004)
invoice.displayInvoice()
# Out:
# -----INVOICE-----
# ID:  1
# Number:  8B3D7F83-F42C-4523-A737-CDCBF7705B77
# Client ID:  1
# Invoice Date:  04/10/2012  12:00:00 a. m.
# Total discount:  500
# DeliveryCharge:  750
# InvoiceDateKey:  20121004

# %% [markdown]
# ### **INVOICELINE**

# %%
class InvoiceLine:
  
  def __init__(self, invoiceLineID, invoiceID, stockID, salePrice, lineItem):
    self.invoiceLineID = invoiceLineID
    self.invoiceID = invoiceID
    self.stockID = stockID
    self.salePrice = salePrice
    self.lineItem = lineItem

  def displayInvoiceLine(self): 
    print('-----INVOICELINE----- ')
    print('Invoiceline ID: ', self.invoiceLineID)
    print('Invoice: ', self.invoiceID)
    print('Stock ID: ', self.stockID)
    print('Sale Price: ', self.salePrice)
    print('Line Item: ', self.lineItem)

# %% [markdown]
# ### **Show results InvoiceLine**

# %%
invoiceLine = InvoiceLine(3, 1, 1, 95000, 1)
invoiceLine.displayInvoiceLine()
# Out:
# -----INVOICELINE-----
# Invoiceline ID:  3
# Invoice:  1
# Stock ID:  1
# Sale Price:  95000
# Line Item:  1

# %% [markdown]
# ### **DATEDIMENSION**

# %%
class DateDimension:
  
  def __init__(self, dateKey, year, monthNum, monthFull, monthAbbr, quarterNum,
              quarterFull, quarterAbbr, yearAndQuarterNum, quarterAbbrAndYear,
              monthAbbrAndYear, monthAndYear, monthName, monthNameAbbr, quarterAndYear,
              quarterAndYearAbbr2, yearAndMonth):
    self.dateKey = dateKey
    self.year = year
    self.monthNum = monthNum
    self.monthFull = monthFull
    self.monthAbbr = monthAbbr
    self.quarterNum = quarterNum
    self.quarterFull = quarterFull
    self.monthNum = monthNum
    self.monthFull = monthFull
    self.quarterAbbr = quarterAbbr
    self.yearAndQuarterNum = yearAndQuarterNum
    self.quarterAbbrAndYear = quarterAbbrAndYear
    self.monthAbbrAndYear = monthAbbrAndYear
    self.monthAndYear = monthAndYear
    self.monthName = monthName
    self.monthNameAbbr = monthNameAbbr
    self.quarterAndYear = quarterAndYear
    self.quarterAndYearAbbr2 = quarterAndYearAbbr2
    self.yearAndMonth = yearAndMonth

  def displayDateDimension(self): 
    print('-----DATE DIMENSION----- ')
    print('Date Key: ', self.dateKey)
    print('Year: ', self.year)
    print('Month num: ', self.monthNum)
    print('Month Full: ', self.monthFull)
    print('Mont Abbr: ', self.monthAbbr)
    print('Quarter Num: ', self.quarterNum)
    print('Quarter Full: ', self.quarterFull)
    print('Quarter Abbr: ', self.quarterAbbr)
    print('Year and Quarter Num: ', self.yearAndQuarterNum)
    print('Quarter Abbr and Year: ', self.quarterAbbrAndYear)
    print('Month Abbr and Year: ', self.monthAbbrAndYear)
    print('Month and Year: ', self.monthAndYear)
    print('Month Name: ', self.monthName)
    print('Month Name Abbr: ', self.monthNameAbbr)
    print('Quarter and Year: ', self.quarterAndYear)
    print('Quarter and Year Abbr2: ', self.quarterAndYearAbbr2)
    print('Year and Month: ', self.yearAndMonth)

# %% [markdown]
# ### **Show results DateDimension**

# %%
dateDimension = DateDimension('19/12/2012', 2012, 12, 'December', 'Dec', 4,
              'Quarter 4', 'Q4', 20124, 'Q4 2012',
              'Dec 2012', 'December 2012', 'December', 'Dec', 'Quarter 4 2012',
              'Qtr 4 2012', 201212)

dateDimension.displayDateDimension()
# Out:
# -----DATE DIMENSION-----
# Date Key:  19/12/2012
# Year:  2012
# Month num:  12
# Month Full:  December
# Mont Abbr:  Dec
# Quarter Num:  4
# Quarter Full:  Quarter 4
# Quarter Abbr:  Q4
# Year and Quarter Num:  20124
# Quarter Abbr and Year:  Q4 2012
# Month Abbr and Year:  Dec 2012
# Month and Year:  December 2012
# Month Name:  December
# Month Name Abbr:  Dec
# Quarter and Year:  Quarter 4 2012
# Quarter and Year Abbr2:  Qtr 4 2012
# Year and Month:  201212

# %% [markdown]
# ### **2. Based on the point number one, define a class to include another kind of transportation vehicle. Include properties and methods that you consider required.**

# %%
class Aircraft:
  def __init__(self,  code, make, model, typeTransport, capacity, price):
    self.code = code
    self.make = make
    self.model = model
    self.typeTransport = typeTransport
    self.capacity = capacity
    self.price = price 

  def displayAircraft(self):
    print('--- AIR TRANSPORT---')
    print('Code: ', self.code)
    print('Make: ', self.make)
    print('Model: ', self.model)
    print('Type Transport: ', self.typeTransport)
    print('Capacity: ', self.capacity, 'Kg')
    print('Price: ', '$', self.price, 'million')

# %% [markdown]
# ### **Show results AirTransport**

# %%
boeing = Aircraft(2, 'Boeing Commercial Airplanes', 'Boeing 747-8', 'Commercial', 447.696, 418.4)
boeing.displayAircraft()
# Out:
# --- AIR TRANSPORT---
# Code:  2
# Make:  Boeing Commercial Airplanes
# Model:  Boeing 747-8
# Type Transport:  Commercial
# Capacity:  447.696 Kg
# Price:  $ 418.4 million

# %% [markdown]
# ### **Exercise 3 - Queries**

# %% [markdown]
# ### **Load information**

# %%
import pandas as pd

# %%
df_Clients = pd.read_excel('./CarSalesDataForReports.xlsx', sheet_name='Clients')
df_Colors = pd.read_excel('./CarSalesDataForReports.xlsx', sheet_name='Colors')
df_Countries = pd.read_excel('./CarSalesDataForReports.xlsx', sheet_name='Countries')
df_Stock = pd.read_excel('./CarSalesDataForReports.xlsx', sheet_name='Stock')
df_Invoices = pd.read_excel('./CarSalesDataForReports.xlsx', sheet_name='Invoices')
df_InvoiceLines = pd.read_excel('./CarSalesDataForReports.xlsx', sheet_name='InvoiceLines')
df_DateDimension = pd.read_excel('./CarSalesDataForReports.xlsx', sheet_name='DateDimension')

# %%
df_Clients.head()
# Out:
#    ClientID     ClientName  ... IsCreditWorthy  IsDealer
# 0         1    Aldo Motors  ...            1.0       NaN
# 1         2    Honest John  ...            0.0       NaN
# 2         3  Bright Orange  ...            0.0       NaN
# 3         4     Cut'n'Shut  ...            1.0       NaN
# 4         5    Wheels'R'Us  ...            1.0       NaN
#
# [5 rows x 15 columns]

# %%
df_Colors.head()
# Out:
#    ColorID          Color
# 0        1            Red
# 1        2           Blue
# 2        3          Green
# 3        4         Silver
# 4        5  Canary Yellow

# %%
df_Countries.head()
# Out:
#    CountryID     CountryName CountryISOCode
# 0          1  United Kingdom            GBR
# 1          2          France            FRA
# 2          3             USA            USA
# 3          4         Germany            DEU
# 4          5           Spain            ESP

# %%
df_Stock.head()
# Out:
#    StockID          Make         Model  ...  Mileage PurchaseDate  VehicleAgeInYears
# 0        1   Rolls Royce      Camargue  ...    52500   2012-01-01          32.539726
# 1        2  Aston Martin           DBS  ...    75000   2012-01-01          10.194521
# 2        3   Rolls Royce  Silver Ghost  ...    52500   2012-01-01          10.860274
# 3        4   Rolls Royce  Silver Ghost  ...   127220   2012-01-01          30.547945
# 4        5   Rolls Royce      Camargue  ...    52500   2012-01-01          32.539726
#
# [5 rows x 12 columns]

# %%
df_Invoices.head()
# Out:
#    InvoiceID  ... InvoiceDateKey
# 0          1  ...       20121004
# 1          2  ...       20120101
# 2          3  ...       20120202
# 3          4  ...       20120303
# 4          5  ...       20120404
#
# [5 rows x 7 columns]

# %%
df_InvoiceLines.head()
# Out:
#    InvoiceLineID  InvoiceID  StockID  SalePrice  LineItem
# 0              3          1        1      95000         1
# 1              4          2        2     120000         1
# 2              5          3        3      88000         1
# 3              6          4        4      89000         1
# 4              7          5        5      92000         1

# %%
df_DateDimension.head()
# Out:
#      DateKey  Year  ...  QuarterAndYearAbbr2 YearAndMonthNum
# 0 2012-01-01  2012  ...           Qtr 1 2012          201201
# 1 2012-01-02  2012  ...           Qtr 1 2012          201201
# 2 2012-01-03  2012  ...           Qtr 1 2012          201201
# 3 2012-01-04  2012  ...           Qtr 1 2012          201201
# 4 2012-01-05  2012  ...           Qtr 1 2012          201201
#
# [5 rows x 17 columns]

# %% [markdown]
# ### **1. Create a query that returns the top 3 car brands most sold (i.e., having the most car brand sales) during first and third quarter of year 2015**

# %% [markdown]
# ##### **Join of tables Stock and InvoiceLines**

# %%
df_StockAndInvoiceLine = df_Stock.join(df_InvoiceLines, how='inner', on='StockID', lsuffix='_right', rsuffix='_left')
df_StockAndInvoiceLine.head()
# Out:
#    StockID  StockID_right          Make  ... StockID_left  SalePrice LineItem
# 0        1              1   Rolls Royce  ...            2     120000        1
# 1        2              2  Aston Martin  ...            3      88000        1
# 2        3              3   Rolls Royce  ...            4      89000        1
# 3        4              4   Rolls Royce  ...            5      92000        1
# 4        5              5   Rolls Royce  ...            6     102500        1
#
# [5 rows x 18 columns]

# %% [markdown]
# ##### **Join of result of Stock and InvoiceLines with Invoices**

# %%
df_full = df_StockAndInvoiceLine.join(df_Invoices, how='inner', on='InvoiceID', lsuffix='_right', rsuffix='_left')
df_full.head()
# Out:
#    InvoiceID  StockID  ...  DeliveryCharge InvoiceDateKey
# 0          2        1  ...            1000       20120202
# 1          3        2  ...            1000       20120303
# 2          4        3  ...            1500       20120404
# 3          5        4  ...            1000       20120504
# 4          6        5  ...             500       20120604
#
# [5 rows x 26 columns]

# %% [markdown]
# ##### **Define quarter 1 and quarter 3**

# %%
df_brands_Q1Q3 = df_full.loc[((df_full.InvoiceDate >= '2015-01-01') & (df_full.InvoiceDate < '2015-04-01')) | ((df_full.InvoiceDate >= '2015-07-01') & (df_full.InvoiceDate < '2015-10-01'))]
df_brands_Q1Q3.head()
# Out:
#      InvoiceID  StockID  ...  DeliveryCharge InvoiceDateKey
# 166        167      167  ...            1725       20150102
# 167        168      168  ...            1725       20150202
# 168        169      169  ...             965       20150302
# 172        173      173  ...             475       20150702
# 173        174      174  ...             975       20150802
#
# [5 rows x 26 columns]

# %% [markdown]
# ##### **Counts which are the best-selling brands and order desc**

# %%
df_top = df_brands_Q1Q3.Make.value_counts().head(3)

print('Top 3 car brands most sold during first and third quarter of year 2015 are: ')
print(df_top)
# Out:
# Top 3 car brands most sold during first and third quarter of year 2015 are:
# Jaguar          30
# Aston Martin    24
# Bentley         18
# Name: Make, dtype: int64

# %% [markdown]
# ### **2. Create a query that shows the top 3 most sold car colors (i.e., having the most car color sales) for each quarter for the years 2012, 2013, 2014, 2015.**

# %% [markdown]
# ##### **Join of tables Stock, InvoiceLines and Invoices it's ready**

# %% [markdown]
# ##### **Join result with Color**

# %%
df_join_color = df_full.join(df_Colors, how='inner', on='ColorID', lsuffix='_right', rsuffix='_left')
df_join_color.head()
# Out:
#     ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left Color
# 0         1          2        1  ...        20120202            2  Blue
# 7         1          9        8  ...        20120904            2  Blue
# 19        1         20       20  ...        20130702            2  Blue
# 20        1         21       21  ...        20130802            2  Blue
# 24        1         25       25  ...        20131202            2  Blue
#
# [5 rows x 29 columns]

# %% [markdown]
# # **----------QUARTER #1 2012 ----------**

# %%
#Define quarter #1 for 2012
df_quarter1_2012 = df_join_color.loc[((df_join_color.InvoiceDate >= '2012-01-01') & (df_join_color.InvoiceDate < '2012-04-01'))]
df_quarter1_2012.head()
# Out:
#     ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left  Color
# 0         1          2        1  ...        20120202            2   Blue
# 37        1         38       38  ...        20120101            2   Blue
# 38        1         39       39  ...        20120201            2   Blue
# 1         2          3        2  ...        20120303            3  Green
# 63        2         64       64  ...        20120301            3  Green
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #1 for the year 2012 and order desc
df_top2012_q1 = df_quarter1_2012.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #1 for the year 2012 are:')
print(df_top2012_q1)
# Out:
# Top 3 colors most sold for quarter #1 for the year 2012 are:
# Blue      3
# Green     2
# Silver    1
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #2 2012 ----------**

# %%
#Define quarter #2 for 2012
df_quarter2_2012 = df_join_color.loc[((df_join_color.InvoiceDate >= '2012-04-01') & (df_join_color.InvoiceDate < '2012-07-01'))]
df_quarter2_2012.head()

# %%
#Counts which are the most color sold for quarter #2 for the year 2012 and order desc

df_top2012_q2 = df_quarter2_2012.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #2 for the year 2012 are:')
print(df_top2012_q2)
# Out:
# Top 3 colors most sold for quarter #2 for the year 2012 are:
# Blue          2
# Green         2
# Night Blue    2
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #3 2012 ----------**

# %%
#Define quarter #3 for 2012
df_quarter3_2012 = df_join_color.loc[((df_join_color.InvoiceDate >= '2012-07-01') & (df_join_color.InvoiceDate < '2012-10-01'))]
df_quarter3_2012.head()
# Out:
#     ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left        Color
# 7         1          9        8  ...        20120904            2         Blue
# 45        3         46       46  ...        20120901            4       Silver
# 43        5         44       44  ...        20120701            6   Night Blue
# 67        5         68       68  ...        20120701            6   Night Blue
# 5         8          7        6  ...        20120704            9  Dark Purple
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #3 for the year 2012 and order desc

df_top2012_q3 = df_quarter3_2012.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #3 for the year 2012 are:')
print(df_top2012_q3)
# Out:
# Top 3 colors most sold for quarter #3 for the year 2012 are:
# Dark Purple    2
# Pink           2
# Night Blue     2
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #4 2012 ----------**

# %%
#Define quarter #4 for 2012
df_quarter4_2012 = df_join_color.loc[((df_join_color.InvoiceDate >= '2012-10-01') & (df_join_color.InvoiceDate < '2013-01-01'))]
df_quarter4_2012.head()
# Out:
#     ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left       Color
# 8         2         10        9  ...        20121104            3       Green
# 46        2         47       47  ...        20121001            3       Green
# 11        5         12       12  ...        20121204            6  Night Blue
# 47        5         48       48  ...        20121101            6  Night Blue
# 72        5         73       73  ...        20121201            6  Night Blue
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #4 for the year 2012 and order desc

df_top2012_q4 = df_quarter4_2012.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #4 for the year 2012 are:')
print(df_top2012_q4)
# Out:
# Top 3 colors most sold for quarter #4 for the year 2012 are:
# Night Blue       3
# Canary Yellow    2
# Black            2
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #1 2013 ----------**

# %%
#Define quarter #1 for 2013
df_quarter1_2013 = df_join_color.loc[((df_join_color.InvoiceDate >= '2013-01-01') & (df_join_color.InvoiceDate < '2013-04-01'))]
df_quarter1_2013.head()
# Out:
#      ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left  Color
# 25         1         26       26  ...        20130102            2   Blue
# 87         1         88       88  ...        20130302            2   Blue
# 135        1        136      136  ...        20130211            2   Blue
# 97         2         98       98  ...        20130102            3  Green
# 98         2         99       99  ...        20130202            3  Green
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #1 for the year 2013 and order desc
df_top2013_q1 = df_quarter1_2013.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #1 for the year 2013 are:')
print(df_top2013_q1)
# Out:
# Top 3 colors most sold for quarter #1 for the year 2013 are:
# Green          5
# Black          4
# Dark Purple    4
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #2 2013 ----------**

# %%
#Define quarter #2 for 2013
df_quarter2_2013 = df_join_color.loc[((df_join_color.InvoiceDate >= '2013-04-01') & (df_join_color.InvoiceDate < '2013-07-01'))]
df_quarter2_2013.head()
# Out:
#      ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left Color
# 53         1         54       54  ...        20130502            2  Blue
# 54         1         55       55  ...        20130602            2  Blue
# 78         1         79       79  ...        20130602            2  Blue
# 113        1        114      114  ...        20130502            2  Blue
# 114        1        115      115  ...        20130602            2  Blue
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #2 for the year 2013 and order desc

df_top2013_q2 = df_quarter2_2013.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #2 for the year 2013 are:')
print(df_top2013_q2)
# Out:
# Top 3 colors most sold for quarter #2 for the year 2013 are:
# Blue      6
# Silver    5
# Black     4
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #3 2013 ----------**

# %%
#Define quarter #3 for 2013
df_quarter3_2013 = df_join_color.loc[((df_join_color.InvoiceDate >= '2013-07-01') & (df_join_color.InvoiceDate < '2013-10-01'))]
df_quarter3_2013.head()
# Out:
#     ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left Color
# 19        1         20       20  ...        20130702            2  Blue
# 20        1         21       21  ...        20130802            2  Blue
# 55        1         56       56  ...        20130702            2  Blue
# 79        1         80       80  ...        20130702            2  Blue
# 80        1         81       81  ...        20130802            2  Blue
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #3 for the year 2013 and order desc

df_top2013_q3 = df_quarter3_2013.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #3 for the year 2013 are:')
print(df_top2013_q3)
# Out:
# Top 3 colors most sold for quarter #3 for the year 2013 are:
# Night Blue       8
# Blue             7
# Canary Yellow    3
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #4 2013 ----------**

# %%
#Define quarter #4 for 2013
df_quarter4_2013 = df_join_color.loc[((df_join_color.InvoiceDate >= '2013-10-01') & (df_join_color.InvoiceDate < '2014-01-01'))]
df_quarter4_2013.head()
# Out:
#      ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left Color
# 24         1         25       25  ...        20131202            2  Blue
# 36         1         37       37  ...        20131202            2  Blue
# 131        1        132      132  ...        20131102            2  Blue
# 132        1        133      133  ...        20131202            2  Blue
# 149        1        150      150  ...        20131125            2  Blue
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #4 for the year 2013 and order desc

df_top2013_q4 = df_quarter4_2013.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #4 for the year 2013 are:')
print(df_top2013_q4)
# Out:
# Top 3 colors most sold for quarter #4 for the year 2013 are:
# Canary Yellow    5
# Blue             5
# Green            5
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #1 2014 ----------**

# %%
#Define quarter #1 for 2014
df_quarter1_2014 = df_join_color.loc[((df_join_color.InvoiceDate >= '2014-01-01') & (df_join_color.InvoiceDate < '2014-04-01'))]
df_quarter1_2014.head()
# Out:
#      ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left Color
# 190        1        191      191  ...        20140101            2  Blue
# 191        1        192      192  ...        20140201            2  Blue
# 192        1        193      193  ...        20140301            2  Blue
# 344        1        344      345  ...        20140101            2  Blue
# 345        1        345      346  ...        20140201            2  Blue
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #1 for the year 2014 and order desc
df_top2014_q1 = df_quarter1_2014.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #1 for the year 2014 are:')
print(df_top2014_q1)
# Out:
# Top 3 colors most sold for quarter #1 for the year 2014 are:
# Blue             6
# Canary Yellow    5
# Night Blue       4
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #2 2014 ----------**

# %%
#Define quarter #2 for 2014
df_quarter2_2014 = df_join_color.loc[((df_join_color.InvoiceDate >= '2014-04-01') & (df_join_color.InvoiceDate < '2014-07-01'))]
df_quarter2_2014.head()
# Out:
#      ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left  Color
# 219        1        220      220  ...        20140601            2   Blue
# 373        1        373      374  ...        20140601            2   Blue
# 157        2        158      158  ...        20140504            3  Green
# 217        2        218      218  ...        20140401            3  Green
# 311        2        311      312  ...        20140504            3  Green
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #2 for the year 2014 and order desc

df_top2014_q2 = df_quarter2_2014.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #2 for the year 2014 are:')
print(df_top2014_q2)
# Out:
# Top 3 colors most sold for quarter #2 for the year 2014 are:
# Green            4
# Silver           2
# Canary Yellow    2
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #3 2014 ----------**

# %%
#Define quarter #3 for 2014
df_quarter3_2014 = df_join_color.loc[((df_join_color.InvoiceDate >= '2014-07-01') & (df_join_color.InvoiceDate < '2014-10-01'))]
df_quarter3_2014.head()
# Out:
#      ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left       Color
# 161        1        162      162  ...        20140904            2        Blue
# 220        1        221      221  ...        20140701            2        Blue
# 315        1        315      316  ...        20140904            2        Blue
# 374        1        374      375  ...        20140701            2        Blue
# 196        5        197      197  ...        20140701            6  Night Blue
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #3 for the year 2014 and order desc

df_top2014_q3 = df_quarter3_2014.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #3 for the year 2014 are:')
print(df_top2014_q3)
# Out:
# Top 3 colors most sold for quarter #3 for the year 2014 are:
# Night Blue     10
# Blue            4
# Dark Purple     2
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #4 2014 ----------**

# %%
#Define quarter #4 for 2014
df_quarter4_2014 = df_join_color.loc[((df_join_color.InvoiceDate >= '2014-10-01') & (df_join_color.InvoiceDate < '2015-01-01'))]
df_quarter4_2014.head()
# Out:
#      ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left   Color
# 162        2        163      163  ...        20141104            3   Green
# 200        2        201      201  ...        20141101            3   Green
# 316        2        316      317  ...        20141104            3   Green
# 354        2        354      355  ...        20141101            3   Green
# 199        3        200      200  ...        20141001            4  Silver
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #4 for the year 2014 and order desc

df_top2014_q4 = df_quarter4_2014.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #4 for the year 2014 are:')
print(df_top2014_q4)
# Out:
# Top 3 colors most sold for quarter #4 for the year 2014 are:
# Canary Yellow    5
# Green            4
# Night Blue       4
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #1 2015 ----------**

# %%
#Define quarter #1 for 2015
df_quarter1_2015 = df_join_color.loc[((df_join_color.InvoiceDate >= '2015-01-01') & (df_join_color.InvoiceDate < '2015-04-01'))]
df_quarter1_2015.head()
# Out:
#      ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left Color
# 179        1        180      180  ...        20150202            2  Blue
# 286        1        287      287  ...        20150109            2  Blue
# 289        1        290      290  ...        20150312            2  Blue
# 333        1        333      334  ...        20150202            2  Blue
# 440        1        440      441  ...        20150109            2  Blue
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #1 for the year 2015 and order desc
df_top2015_q1 = df_quarter1_2015.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #1 for the year 2015 are:')
print(df_top2015_q1)
# Out:
# Top 3 colors most sold for quarter #1 for the year 2015 are:
# Green          12
# Night Blue     10
# Dark Purple     8
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #2 2015 ----------**

# %%
#Define quarter #2 for 2015
df_quarter2_2015 = df_join_color.loc[((df_join_color.InvoiceDate >= '2015-04-01') & (df_join_color.InvoiceDate < '2015-07-01'))]
df_quarter2_2015.head()
# Out:
#      ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left Color
# 207        1        208      208  ...        20150602            2  Blue
# 241        1        242      242  ...        20150402            2  Blue
# 265        1        266      266  ...        20150402            2  Blue
# 267        1        268      268  ...        20150602            2  Blue
# 296        1        297      297  ...        20150519            2  Blue
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #2 for the year 2015 and order desc

df_top2015_q2 = df_quarter2_2015.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #2 for the year 2015 are:')
print(df_top2015_q2)
# Out:
# Top 3 colors most sold for quarter #2 for the year 2015 are:
# British Racing Green    10
# Blue                    10
# Silver                   8
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #3 2015 ----------**

# %%
#Define quarter #3 for 2015
df_quarter3_2015 = df_join_color.loc[((df_join_color.InvoiceDate >= '2015-07-01') & (df_join_color.InvoiceDate < '2015-10-01'))]
df_quarter3_2015.head()
# Out:
#      ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left Color
# 173        1        174      174  ...        20150802            2  Blue
# 174        1        175      175  ...        20150902            2  Blue
# 208        1        209      209  ...        20150702            2  Blue
# 209        1        210      210  ...        20150802            2  Blue
# 232        1        233      233  ...        20150702            2  Blue
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #3 for the year 2015 and order desc

df_top2015_q3 = df_quarter3_2015.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #3 for the year 2015 are:')
print(df_top2015_q3)
# Out:
# Top 3 colors most sold for quarter #3 for the year 2015 are:
# Blue             22
# Night Blue       14
# Canary Yellow     6
# Name: Color, dtype: int64

# %% [markdown]
# # **----------QUARTER #4 2015 ----------**

# %%
#Define quarter #4 for 2015
df_quarter4_2015 = df_join_color.loc[((df_join_color.InvoiceDate >= '2015-10-01') & (df_join_color.InvoiceDate <= '2015-12-31'))]
df_quarter4_2015.head()
# Out:
#      ColorID  InvoiceID  StockID  ...  InvoiceDateKey ColorID_left Color
# 249        1        250      250  ...        20151202            2  Blue
# 285        1        286      286  ...        20151202            2  Blue
# 303        1        304      304  ...        20151126            2  Blue
# 403        1        403      404  ...        20151202            2  Blue
# 439        1        439      440  ...        20151202            2  Blue
#
# [5 rows x 29 columns]

# %%
#Counts which are the most color sold for quarter #4 for the year 2015 and order desc

df_top2015_q4 = df_quarter4_2015.Color.value_counts().head(3)

print('Top 3 colors most sold for quarter #4 for the year 2015 are: ')
print(df_top2015_q4)
# Out:
# Top 3 colors most sold for quarter #4 for the year 2015 are:
# Canary Yellow    10
# Green            10
# Pink              8
# Name: Color, dtype: int64
